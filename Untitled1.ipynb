# %%
import networkx as nx
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
dt = pd.read_csv('DenverCrime.csv')

# %%
dt
# Out:
#         INCIDENT_ID         OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0        2016376978   2016376978521300          5213                       0
# 1       20186000994  20186000994239900          2399                       0
# 2       20166003953  20166003953230500          2305                       0
# 3         201872333    201872333239900          2399                       0
# 4        2017411405   2017411405230300          2303                       0
# ...             ...                ...           ...                     ...
# 494486   2018836985   2018836985549900          5499                       0
# 494487  20188058998  20188058998260201          2602                       1
# 494488   2018848306   2018848306544100          5441                       0
# 494489   2018831000   2018831000549900          5499                       0
# 494490  20186012081  20186012081230400          2304                       0
#
# ...

# %%
for activity in criminal_activities:
    individual = activity["individual"]
    crime = activity["crime"]
    
    criminal_network.add_node(individual)
    
    for other_activity in criminal_activities:
        other_individual = other_activity["individual"]
        if other_individual != individual:
            criminal_network.add_edge(individual, other_individual)

# %%
centrality = nx.degree_centrality(criminal_network)
